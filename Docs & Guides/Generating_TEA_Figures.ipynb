# %% [markdown]
# # Generating TEA Figures
#
# This notebook generates the TEA network figures used in the README.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
import teanets as tea

# %% [markdown]
# ## 1. Framework overview (`tea_overview.jpg`)
#
# Three sentences covering passive voice, active voice, and negative valence:

# %%
text = (
    "Mark and Rose go to the park. "
    "The hacker destroyed the sensitive database."
    "The physician and the doctor were praised by the hospital."
)

svo = tea.extract_svos_from_text(text)
display(svo)
# Out:
# ...
# Inference: 100%|██████████| 1/1 [00:00<00:00, 76.35it/s]
#        Node 1     TEA              Node 2    TEA2  \
# 0        mark   Agent                  go   Event
# 1        rose   Agent                  go   Event
# 2          go   Event             to park  Target
# 3        mark   Agent                rose   Agent
# 4      hacker   Agent             destroy   Event
# 5     destroy   Event  sensitive database  Target
# 6    hospital   Agent              praise   Event
# 7      praise   Event           physician  Target
# 8      praise   Event              doctor  Target
# 9   physician  Target              doctor  Target
# 10     doctor  Target           physician  Target
#
#                                            Hypergraph  Semantic-Syntactic  \
# 0   [[('mark', []), ('rose', [])], ['go'], [('to p...                   0
# 1   [[('mark', []), ('rose', [])], ['go'], [('to p...                   0
# 2   [[('mark', []), ('rose', [])], ['go'], [('to p...                   0
# ...

# %%
tea.plot_svo_graph(svo, filename='../tea_overview.jpg')

# %% [markdown]
# ## 2. Quickstart (`tea_quickstart.jpg`)
#
# A single sentence with one agent performing two actions:

# %%
text = """The physician and the doctor were praised by the hospital."""

svo = tea.extract_svos_from_text(text)
display(svo)
# Out:
# ...
# Inference: 100%|██████████| 1/1 [00:00<00:00, 92.76it/s]
#       Node 1     TEA     Node 2    TEA2  \
# 0   hospital   Agent     praise   Event
# 1     praise   Event  physician  Target
# 2     praise   Event     doctor  Target
# 3  physician  Target     doctor  Target
# 4     doctor  Target  physician  Target
#
#                                           Hypergraph  Semantic-Syntactic  \
# 0  [[('hospital', [])], ['praise'], [('physician'...                   0
# 1  [[('hospital', [])], ['praise'], [('physician'...                   0
# 2  [[('hospital', [])], ['praise'], [('physician'...                   0
# 3  [[('hospital', [])], ['praise'], [('physician'...                   0
# 4                                                N/A                   1
#
#   svo_id  passive_approx  is_passive
# 0      0               0           1
# 1      0               0           1
# 2      0               0           1
# 3      0               0           1
# ...

# %%
tea.plot_svo_graph(svo, filename='../tea_quickstart_passive.jpg')

# %% [markdown]
# ## 3. Multi-sentence example (`tea_multisentence.jpg`)
#
# Two sentences with mixed valence — negative exposure and positive praise:

# %%
text = (
    "The system detected an error. Finally, the loaf was sold."
    "The mayor praised the volunteers and thanked the community."
)

svo = tea.extract_svos_from_text(text)
display(svo)
# Out:
# ...
# Inference: 100%|██████████| 1/1 [00:00<00:00, 73.71it/s]
#    Node 1    TEA        Node 2    TEA2  \
# 0  system  Agent        detect   Event
# 1  detect  Event         error  Target
# 2    loaf  Agent  finally sell   Event
# 3   mayor  Agent        praise   Event
# 4  praise  Event     volunteer  Target
# 5   mayor  Agent         thank   Event
# 6   thank  Event     community  Target
#
#                                           Hypergraph  Semantic-Syntactic  \
# 0  [[('system', [])], ['detect'], [('error', [])]...                   0
# 1  [[('system', [])], ['detect'], [('error', [])]...                   0
# 2  [[('loaf', [])], ['finally sell'], [], True, T...                   0
# 3  [[('mayor', [])], ['praise'], [('volunteer', [...                   0
# 4  [[('mayor', [])], ['praise'], [('volunteer', [...                   0
# 5  [[('mayor', [])], ['thank'], [('community', []...                   0
# 6  [[('mayor', [])], ['thank'], [('community', []...                   0
#
# ...

# %%
tea.plot_svo_graph(svo, filename='../tea_multisentence.jpg')
