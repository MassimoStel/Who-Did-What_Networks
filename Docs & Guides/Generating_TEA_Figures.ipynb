# %% [markdown]
# # Generating TEA Figures
#
# This notebook generates the TEA network figures used in the README.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
import teanets as tea

# %% [markdown]
# ## 1. Framework overview (`tea_overview.jpg`)
#
# Three sentences covering passive voice, active voice, and negative valence:

# %%
text = (
    "The mayor was impressed by the citizen. "
    "Mark and Rose go to the park. "
    "The criminal attacked Mark and Rose."
)

svo = tea.extract_svos_from_text(text)
display(svo)
# Out:
# Map: 100%|██████████| 1/1 [00:00<00:00, 417.55 examples/s]
# Inference: 100%|██████████| 1/1 [00:00<00:00, 78.89it/s]
#      Node 1     TEA   Node 2    TEA2  \
# 0   citizen   Agent  impress   Event
# 1   impress   Event    mayor  Target
# 2      mark   Agent       go   Event
# 3      rose   Agent       go   Event
# 4        go   Event  to park  Target
# 5      mark   Agent     rose   Agent
# 6  criminal   Agent   attack   Event
# 7    attack   Event     mark  Target
# 8    attack   Event     rose  Target
# 9      mark  Target     rose  Target
#
#                                           Hypergraph  Semantic-Syntactic  \
# 0  [[('citizen', [])], ['impress'], [('mayor', []...                   0
# 1  [[('citizen', [])], ['impress'], [('mayor', []...                   0
# 2  [[('mark', []), ('rose', [])], ['go'], [('to p...                   0
# 3  [[('mark', []), ('rose', [])], ['go'], [('to p...                   0
# 4  [[('mark', []), ('rose', [])], ['go'], [('to p...                   0
# 5  [[('mark', []), ('rose', [])], ['go'], [('to p...                   0
# 6  [[('criminal', [])], ['attack'], [('mark', [])...                   0
# 7  [[('criminal', [])], ['attack'], [('mark', [])...                   0
# 8  [[('criminal', [])], ['attack'], [('mark', [])...                   0
# 9  [[('criminal', [])], ['attack'], [('mark', [])...                   0
#
#    svo_id  passive_approx  is_passive
# 0       0               0           1
# 1       0               0           1
# 2       1               0           0
# 3       1               0           0
# 4       1               0           0
# 5       1               0           0
# 6       2               0           0
# 7       2               0           0
# 8       2               0           0
# 9       2               0           0

# %%
tea.plot_svo_graph(svo, filename='../tea_overview.jpg')

# %% [markdown]
# ## 2. Quickstart (`tea_quickstart.jpg`)
#
# A single sentence with one agent performing two actions:

# %%
text = """The baker prepared a fresh sourdough after customers asked for healthier bread. Finally, the loaf was sold by the clerk."""

svo = tea.extract_svos_from_text(text)
display(svo)
# Out:
# Map: 100%|██████████| 1/1 [00:00<00:00, 360.21 examples/s]
# Inference: 100%|██████████| 1/1 [00:00<00:00, 77.31it/s]
#          Node 1    TEA             Node 2    TEA2  \
# 0         baker  Agent            prepare   Event
# 1       prepare  Event    fresh sourdough  Target
# 2      customer  Agent                ask   Event
# 3           ask  Event  for healthy bread  Target
# 4         clerk  Agent       finally sell   Event
# 5  finally sell  Event               loaf  Target
#
#                                           Hypergraph  Semantic-Syntactic  \
# 0  [[('baker', [])], ['prepare'], [('fresh sourdo...                   0
# 1  [[('baker', [])], ['prepare'], [('fresh sourdo...                   0
# 2  [[('customer', [])], ['ask'], [('for healthy b...                   0
# 3  [[('customer', [])], ['ask'], [('for healthy b...                   0
# 4  [[('clerk', [])], ['finally sell'], [('loaf', ...                   0
# 5  [[('clerk', [])], ['finally sell'], [('loaf', ...                   0
#
#    svo_id  passive_approx  is_passive
# 0       0               0           0
# 1       0               0           0
# 2       1               0           0
# 3       1               0           0
# 4       2               0           1
# 5       2               0           1

# %%
tea.plot_svo_graph(svo, filename='../tea_quickstart.jpg')

# %% [markdown]
# ## 3. Multi-sentence example (`tea_multisentence.jpg`)
#
# Two sentences with mixed valence — negative exposure and positive praise:

# %%
text = (
    "The journalist exposed the corruption. "
    "The mayor praised the volunteers and thanked the community."
)

svo = tea.extract_svos_from_text(text)
display(svo)
# Out:
# Map: 100%|██████████| 1/1 [00:00<00:00, 423.97 examples/s]
# Inference: 100%|██████████| 1/1 [00:00<00:00, 86.01it/s]
#        Node 1    TEA      Node 2    TEA2  \
# 0  journalist  Agent      expose   Event
# 1      expose  Event  corruption  Target
# 2       mayor  Agent      praise   Event
# 3      praise  Event   volunteer  Target
# 4       mayor  Agent       thank   Event
# 5       thank  Event   community  Target
#
#                                           Hypergraph  Semantic-Syntactic  \
# 0  [[('journalist', [])], ['expose'], [('corrupti...                   0
# 1  [[('journalist', [])], ['expose'], [('corrupti...                   0
# 2  [[('mayor', [])], ['praise'], [('volunteer', [...                   0
# 3  [[('mayor', [])], ['praise'], [('volunteer', [...                   0
# 4  [[('mayor', [])], ['thank'], [('community', []...                   0
# 5  [[('mayor', [])], ['thank'], [('community', []...                   0
#
#    svo_id  passive_approx  is_passive
# 0       0               0           0
# 1       0               0           0
# 2       1               0           0
# 3       1               0           0
# 4       2               0           0
# 5       2               0           0

# %%
tea.plot_svo_graph(svo, filename='../tea_multisentence.jpg')
